# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn-darkgrid')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9416\448178554.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')

# %%
x = np.arange(-50, 50)
y1 = np.power(x, 2)
y2 = np.power(x, 3)
y3 = np.sin(x)
y4 = np.cos(x)
y5 = np.tan(x)
y6 = np.tanh(x)
y7 = np.sinh(x)
y8 = np.cosh(x)
y9 = np.exp(x)

fig1, ax1 = plt.subplots(nrows = 3, ncols = 3, figsize = (20, 20))
ax1[0, 0].plot(x, y1, "tab:blue")
ax1[0, 0].set_title("Square Function")
ax1[0, 0].set_xlabel('X', fontsize = 18)
ax1[0, 0].set_ylabel('Y', fontsize = 18)

ax1[0, 1].plot(x, y2, "tab:orange")
ax1[0, 1].set_title("Cubic Function")
ax1[0, 1].set_xlabel('X', fontsize = 18)
ax1[0, 1].set_ylabel('Y', fontsize = 18)

ax1[0, 2].plot(x, y3, "tab:green")
ax1[0, 2].set_title("Sine Function")
ax1[0, 2].set_xlabel('X', fontsize = 18)
ax1[0, 2].set_ylabel('Y', fontsize = 18)

ax1[1, 0].plot(x, y4, "b-")
ax1[1, 0].set_title("Cosine Function")
ax1[1, 0].set_xlabel('X', fontsize = 18)
ax1[1, 0].set_ylabel('Y', fontsize = 18)

ax1[1, 1].plot(x, y5, "r-")
ax1[1, 1].set_title("Tangent Function")
ax1[1, 1].set_xlabel('X', fontsize = 18)
ax1[1, 1].set_ylabel('Y', fontsize = 18)

ax1[1, 2].plot(x, y6, "g-")
ax1[1, 2].set_title("Hyperbolic Tangent")
ax1[1, 2].set_xlabel('X', fontsize = 18)
ax1[1, 2].set_ylabel('Y', fontsize = 18)

ax1[2, 0].plot(x, y7, "m-")
ax1[2, 0].set_title("Hyperbolic Sine")
ax1[2, 0].set_xlabel('X', fontsize = 18)
ax1[2, 0].set_ylabel('Y', fontsize = 18)

ax1[2, 1].plot(x, y8, "y-")
ax1[2, 1].set_title("Hyperbolic Cosine")
ax1[2, 1].set_xlabel('X', fontsize = 18)
ax1[2, 1].set_ylabel('Y', fontsize = 18)

ax1[2, 2].plot(x, y9, "k-")
ax1[2, 2].set_title("Exponential Function")
ax1[2, 2].set_xlabel('X', fontsize = 18)
ax1[2, 2].set_ylabel('Y', fontsize = 18)

plt.show()

# %%
# 2

# %%
x1 = np.array([13, 45, 79, 24, 53, 90])
y1 = np.array([100, 400, 366, 256, 890, 234])

x2 = np.array([70, 80, 25, 44, 93, 67])
y2 = np.array([500, 900, 234, 123, 567, 765])

#1.graph
plt.scatter(x1, y1)
plt.xlabel('Time Spent', fontsize = 12)
plt.ylabel('Score', fontsize = 12)
plt.title('Scatter Graph')
plt.show()

# %%
#2.graph
plt.scatter(x2, y2, color = 'r')
plt.xlabel('Time Spent', fontsize = 12)
plt.ylabel('Score', fontsize = 12)
plt.title('Scatter Graph')
plt.show()

# %%
#merge
plt.scatter(x1, y1, label = 'Class 1', color = 'r')
plt.scatter(x2, y2, label = 'Class 2', color = 'm')
plt.xlabel('Time Spent', fontsize = 12)
plt.ylabel('Score', fontsize = 12)
plt.title('Scatter Graph')
plt.legend()
plt.show()

# %%
#different shapes
plt.scatter(x1, y1, label = 'Class 1', marker = 'o', color = 'b')
plt.scatter(x2, y2, label = 'Class 2', marker = 'v', color = 'r')
plt.xlabel('Time Spent', fontsize = 12)
plt.ylabel('Score', fontsize = 12)
plt.title('Scatter Graph')
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.scatter(np.random.random(10), np.random.random(10), c = 'r', s = 50, alpha = 0.6, label = 'One')
plt.scatter(np.random.random(10), np.random.random(10), c = 'b', s = 100, alpha = 0.6, label = 'Two')
plt.scatter(np.random.random(10), np.random.random(10), c = 'g', s = 150, alpha = 0.6, label = 'Three')
plt.scatter(np.random.random(10), np.random.random(10), c = 'y', s = 200, alpha = 0.6, label = 'Four')
plt.legend(bbox_to_anchor = (1.0, 1.0), shadow = True, fontsize = 'x-large')
plt.show()

# %%
plt.figure(figsize = (8, 6))
plt.rcParams['text.color'] = 'blue'
plt.scatter(np.random.random(10), np.random.random(10), c = 'r', s = 50, alpha = 0.6, label = 'One')
plt.scatter(np.random.random(10), np.random.random(10), c = 'b', s = 100, alpha = 0.6, label = 'Two')
plt.scatter(np.random.random(10), np.random.random(10), c = 'g', s = 150, alpha = 0.6, label = 'Three')
plt.scatter(np.random.random(10), np.random.random(10), c = 'y', s = 200, alpha = 0.6, label = 'Four')
plt.legend(bbox_to_anchor = (1.0, 1.0), shadow = True, fontsize = 'x-large')
plt.show()

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault)
plt.style.use('seaborn-darkgrid')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9416\2882732935.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')
